# %% [markdown]
# <a href="https://colab.research.google.com/github/jackqk/pandas-note/blob/master/DataFrame_CRUD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataFrame CRUD**

# %% [markdown]
# # **一、Creation**

# %% [markdown]
# ## Row 创建

# %%
# list+dict
import pandas as pd
df = pd.DataFrame([{'growth':.5, 'Name':'Paul'}, {'growth':.7, 'Name':'George'}, {'growth':1.2, 'Name':'Ringo'}])
df
# Out:
#    growth    Name
# 0     0.5    Paul
# 1     0.7  George
# 2     1.2   Ringo

# %%
# list+tuple+index
df = pd.DataFrame([(5, 'Paul'), (7, 'George'), (1.2, 'Ringo')], columns=['growth', 'Name'])
df
# Out:
#    growth    Name
# 0     5.0    Paul
# 1     7.0  George
# 2     1.2   Ringo

# %%
s1 = pd.Series({'growth':.5, 'Name':'Paul'})
s2 = pd.Series({'growth':.7, 'Name':'George'})
s3 = pd.Series({'growth':1.2, 'Name':'Ringo'})
df = pd.DataFrame([s1, s2, s3])
df
# Out:
#    growth    Name
# 0     0.5    Paul
# 1     0.7  George
# 2     1.2   Ringo

# %% [markdown]
# ## Columns 创建

# %%
# dict+list
import pandas as pd
df = pd.DataFrame({'growth':[.5, .7, 1.2], 'Name':['Paul', 'George', 'Ringo']})
df
# Out:
#    growth    Name
# 0     0.5    Paul
# 1     0.7  George
# 2     1.2   Ringo

# %% [markdown]
# ## Numpy 创建

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(10, 3), columns=['a', 'b', 'c'])
df
# Out:
#           a         b         c
# 0 -0.495711  0.843352 -0.124422
# 1  0.680442 -1.068099  0.058544
# 2  0.898556  0.885288 -0.003347
# 3 -0.637260 -0.645002  0.005564
# 4 -2.139233  0.794628 -1.214997
# 5 -0.313396  0.128956 -0.105759
# 6  0.590068  0.173256 -1.797408
# 7  0.677359  1.169891  0.928835
# 8 -0.056904 -0.170867  2.056720
# 9  0.378893  0.445405 -1.657161

# %% [markdown]
# ## CSV创建

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/irJERAD/Intro-to-Data-Science-in-Python/master/MyNotebooks/olympics.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                    0         1     2     3  ...    12    13    14              15
# 0                NaN  № Summer  01 !  02 !  ...  01 !  02 !  03 !  Combined total
# 1  Afghanistan (AFG)        13     0     0  ...     0     0     2               2
# 2      Algeria (ALG)        12     5     2  ...     5     2     8              15
# 3    Argentina (ARG)        23    18    24  ...    18    24    28              70
# 4      Armenia (ARM)         5     1     2  ...     1     2     9              12
#
# [5 rows x 16 columns]

# %%
#针对上面index和column name的值做一下改进
df = pd.read_csv(url, index_col=0, skiprows=1)
for col in df.columns:
  if col[:2] == '01':
    df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
  if col[:2] == '02':
    df.rename(columns={col : 'Silver'+col[4:]}, inplace=True)
  if col[:2] == '03':
    df.rename(columns={col : 'Bronze' + col[4:]}, inplace=True)
  if col[:1] == '№':
    df.rename(columns={col: '#' + col[2:]}, inplace=True)
df.head()
# Out:
#                          #Summer  Gold  ...  Bronze.2  Combined total
# Afghanistan (AFG)             13     0  ...         2               2
# Algeria (ALG)                 12     5  ...         8              15
# Argentina (ARG)               23    18  ...        28              70
# Armenia (ARM)                  5     1  ...         9              12
# Australasia (ANZ) [ANZ]        2     3  ...         5              12
#
# [5 rows x 15 columns]

# %% [markdown]
# # **二、Insert**

# %% [markdown]
# ## 插入行

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/jackqk/pandas-note/master/data/sample1.csv'
df = pd.read_csv(url)
df
# Out:
#                              LOCATION  MILES  ELEVATION    CUMUL %CUMUL GAIN
# 0        Big Mountain Pass AidStation  39.07       7432  11579.0       43.8%
# 1                    Mules Ear Meadow  40.75       7478  12008.0       45.4%
# 2                       Bald Mountain  42.46       7869  12593.0       47.6%
# 3                         Pence Point  43.99       7521  12813.0       48.4%
# 4         Alexander Ridge Aid Station  46.90       6160  13169.0       49.8%
# 5                   Alexander Springs  47.97       5956  13319.0       50.3%
# 6               Rogers Trail junction  49.52       6698  13967.0       52.8%
# 7                       Rogers Saddle  49.77       6790  14073.0       53.2%
# 8                        Railroad Bed  50.15       6520      NaN         NaN
# 9  Lambs Canyon Underpass Aid Station  52.48       6111  14329.0       54.2%

# %%
df2 = pd.DataFrame([('Lambs Trail', 54.14, 6628, 14805, '56.0%')], columns=['LOCATION', 'MILES', 'ELEVATION', 'CUMUL', '% CUMUL GAIN'])
df2
# Out:
#       LOCATION  MILES  ELEVATION  CUMUL % CUMUL GAIN
# 0  Lambs Trail  54.14       6628  14805        56.0%

# %%
# concat
# 原始数据不会修改
# ignore_index=False，看最后数字索引
pd.concat([df, df2], ignore_index=True, sort=False)
# Out:
#                               LOCATION  MILES  ...  %CUMUL GAIN  % CUMUL GAIN
# 0         Big Mountain Pass AidStation  39.07  ...        43.8%           NaN
# 1                     Mules Ear Meadow  40.75  ...        45.4%           NaN
# 2                        Bald Mountain  42.46  ...        47.6%           NaN
# 3                          Pence Point  43.99  ...        48.4%           NaN
# 4          Alexander Ridge Aid Station  46.90  ...        49.8%           NaN
# 5                    Alexander Springs  47.97  ...        50.3%           NaN
# 6                Rogers Trail junction  49.52  ...        52.8%           NaN
# 7                        Rogers Saddle  49.77  ...        53.2%           NaN
# 8                         Railroad Bed  50.15  ...          NaN           NaN
# 9   Lambs Canyon Underpass Aid Station  52.48  ...        54.2%           NaN
# 10                         Lambs Trail  54.14  ...          NaN         56.0%
#
# [11 rows x 6 columns]

# %%
#用法与上面的差不多
df.append(df2, sort=False, ignore_index=True)
# Out:
#                               LOCATION  MILES  ...  %CUMUL GAIN  % CUMUL GAIN
# 0         Big Mountain Pass AidStation  39.07  ...        43.8%           NaN
# 1                     Mules Ear Meadow  40.75  ...        45.4%           NaN
# 2                        Bald Mountain  42.46  ...        47.6%           NaN
# 3                          Pence Point  43.99  ...        48.4%           NaN
# 4          Alexander Ridge Aid Station  46.90  ...        49.8%           NaN
# 5                    Alexander Springs  47.97  ...        50.3%           NaN
# 6                Rogers Trail junction  49.52  ...        52.8%           NaN
# 7                        Rogers Saddle  49.77  ...        53.2%           NaN
# 8                         Railroad Bed  50.15  ...          NaN           NaN
# 9   Lambs Canyon Underpass Aid Station  52.48  ...        54.2%           NaN
# 10                         Lambs Trail  54.14  ...          NaN         56.0%
#
# [11 rows x 6 columns]

# %% [markdown]
# ## 插入列

# %%
# 直接加
df['bogus'] = pd.Series(range(11))
df
# Out:
#                              LOCATION  MILES  ...  %CUMUL GAIN  bogus
# 0        Big Mountain Pass AidStation  39.07  ...        43.8%      0
# 1                    Mules Ear Meadow  40.75  ...        45.4%      1
# 2                       Bald Mountain  42.46  ...        47.6%      2
# 3                         Pence Point  43.99  ...        48.4%      3
# 4         Alexander Ridge Aid Station  46.90  ...        49.8%      4
# 5                   Alexander Springs  47.97  ...        50.3%      5
# 6               Rogers Trail junction  49.52  ...        52.8%      6
# 7                       Rogers Saddle  49.77  ...        53.2%      7
# 8                        Railroad Bed  50.15  ...          NaN      8
# 9  Lambs Canyon Underpass Aid Station  52.48  ...        54.2%      9
#
# [10 rows x 6 columns]

# %%
# 以函数形式加
def aid_station(val):
  return 'Station' in val

df['STATION']=df['LOCATION'].apply(aid_station)
df
# Out:
#                              LOCATION  MILES  ...  bogus  STATION
# 0        Big Mountain Pass AidStation  39.07  ...      0     True
# 1                    Mules Ear Meadow  40.75  ...      1    False
# 2                       Bald Mountain  42.46  ...      2    False
# 3                         Pence Point  43.99  ...      3    False
# 4         Alexander Ridge Aid Station  46.90  ...      4     True
# 5                   Alexander Springs  47.97  ...      5    False
# 6               Rogers Trail junction  49.52  ...      6    False
# 7                       Rogers Saddle  49.77  ...      7    False
# 8                        Railroad Bed  50.15  ...      8    False
# 9  Lambs Canyon Underpass Aid Station  52.48  ...      9     True
#
# [10 rows x 7 columns]

# %% [markdown]
# # **三、update**

# %% [markdown]
# # **四、 Delete**

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/jackqk/pandas-note/master/data/sample1.csv'
df = pd.read_csv(url)
df
# Out:
#                              LOCATION  MILES  ELEVATION    CUMUL %CUMUL GAIN
# 0        Big Mountain Pass AidStation  39.07       7432  11579.0       43.8%
# 1                    Mules Ear Meadow  40.75       7478  12008.0       45.4%
# 2                       Bald Mountain  42.46       7869  12593.0       47.6%
# 3                         Pence Point  43.99       7521  12813.0       48.4%
# 4         Alexander Ridge Aid Station  46.90       6160  13169.0       49.8%
# 5                   Alexander Springs  47.97       5956  13319.0       50.3%
# 6               Rogers Trail junction  49.52       6698  13967.0       52.8%
# 7                       Rogers Saddle  49.77       6790  14073.0       53.2%
# 8                        Railroad Bed  50.15       6520      NaN         NaN
# 9  Lambs Canyon Underpass Aid Station  52.48       6111  14329.0       54.2%

# %% [markdown]
# ## delete rows（删除行）

# %%
# drop传入index
df.drop([5,9])
# Out:
#                        LOCATION  MILES  ELEVATION    CUMUL %CUMUL GAIN
# 0  Big Mountain Pass AidStation  39.07       7432  11579.0       43.8%
# 1              Mules Ear Meadow  40.75       7478  12008.0       45.4%
# 2                 Bald Mountain  42.46       7869  12593.0       47.6%
# 3                   Pence Point  43.99       7521  12813.0       48.4%
# 4   Alexander Ridge Aid Station  46.90       6160  13169.0       49.8%
# 6         Rogers Trail junction  49.52       6698  13967.0       52.8%
# 7                 Rogers Saddle  49.77       6790  14073.0       53.2%
# 8                  Railroad Bed  50.15       6520      NaN         NaN

# %%
# print(df.index)
# df.drop(df.index[0:4:2])
df.drop(df.index[0:10:2])
# Out:
#                              LOCATION  MILES  ELEVATION    CUMUL %CUMUL GAIN
# 1                    Mules Ear Meadow  40.75       7478  12008.0       45.4%
# 3                         Pence Point  43.99       7521  12813.0       48.4%
# 5                   Alexander Springs  47.97       5956  13319.0       50.3%
# 7                       Rogers Saddle  49.77       6790  14073.0       53.2%
# 9  Lambs Canyon Underpass Aid Station  52.48       6111  14329.0       54.2%

# %% [markdown]
# ## delete column（删除列）

# %%
# 默认inplase=False
display(df.drop('MILES', axis=1))
print
df  #MILE在原始数据不变
# Out:
#                              LOCATION  ELEVATION    CUMUL %CUMUL GAIN
# 0        Big Mountain Pass AidStation       7432  11579.0       43.8%
# 1                    Mules Ear Meadow       7478  12008.0       45.4%
# 2                       Bald Mountain       7869  12593.0       47.6%
# 3                         Pence Point       7521  12813.0       48.4%
# 4         Alexander Ridge Aid Station       6160  13169.0       49.8%
# 5                   Alexander Springs       5956  13319.0       50.3%
# 6               Rogers Trail junction       6698  13967.0       52.8%
# 7                       Rogers Saddle       6790  14073.0       53.2%
# 8                        Railroad Bed       6520      NaN         NaN
# 9  Lambs Canyon Underpass Aid Station       6111  14329.0       54.2%
#                              LOCATION  MILES  ELEVATION    CUMUL %CUMUL GAIN
# 0        Big Mountain Pass AidStation  39.07       7432  11579.0       43.8%
# 1                    Mules Ear Meadow  40.75       7478  12008.0       45.4%
# 2                       Bald Mountain  42.46       7869  12593.0       47.6%
# 3                         Pence Point  43.99       7521  12813.0       48.4%
# 4         Alexander Ridge Aid Station  46.90       6160  13169.0       49.8%
# 5                   Alexander Springs  47.97       5956  13319.0       50.3%
# 6               Rogers Trail junction  49.52       6698  13967.0       52.8%
# 7                       Rogers Saddle  49.77       6790  14073.0       53.2%
# 8                        Railroad Bed  50.15       6520      NaN         NaN
# 9  Lambs Canyon Underpass Aid Station  52.48       6111  14329.0       54.2%

# %%
# 原始数据直接干掉了
df.pop('LOCATION')
df
# Out:
#    MILES  ELEVATION    CUMUL %CUMUL GAIN
# 0  39.07       7432  11579.0       43.8%
# 1  40.75       7478  12008.0       45.4%
# 2  42.46       7869  12593.0       47.6%
# 3  43.99       7521  12813.0       48.4%
# 4  46.90       6160  13169.0       49.8%
# 5  47.97       5956  13319.0       50.3%
# 6  49.52       6698  13967.0       52.8%
# 7  49.77       6790  14073.0       53.2%
# 8  50.15       6520      NaN         NaN
# 9  52.48       6111  14329.0       54.2%

# %%
# 原始数据直接干掉了
del df['CUMUL']
df
# Out:
#    MILES  ELEVATION %CUMUL GAIN
# 0  39.07       7432       43.8%
# 1  40.75       7478       45.4%
# 2  42.46       7869       47.6%
# 3  43.99       7521       48.4%
# 4  46.90       6160       49.8%
# 5  47.97       5956       50.3%
# 6  49.52       6698       52.8%
# 7  49.77       6790       53.2%
# 8  50.15       6520         NaN
# 9  52.48       6111       54.2%

# %% [markdown]
# # **Dealing With Missing Data**

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'Name':['Fred', 'Sally', 'George', 'Fido'],
           'Age':[22, 29, 24, None],
           'Color':['Red', 'Blue', np.nan, 'Black']})
df
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0    NaN
# 3    Fido   NaN  Black

# %% [markdown]
# ## Find Valid Data

# %%
valid = df.notnull()
#寻找某列不为空的所有值
df[valid['Age']]
# Out:
#      Name   Age Color
# 0    Fred  22.0   Red
# 1   Sally  29.0  Blue
# 2  George  24.0   NaN

# %%
df[valid['Color']]
# Out:
#     Name   Age  Color
# 0   Fred  22.0    Red
# 1  Sally  29.0   Blue
# 3   Fido   NaN  Black

# %%
#这种情况与dropna结果一样。
df[valid['Age'] & valid['Color']]
# Out:
#     Name   Age Color
# 0   Fred  22.0   Red
# 1  Sally  29.0  Blue

# %% [markdown]
# ## Finding Missing Data

# %%
df.isnull()
# Out:
#     Name    Age  Color
# 0  False  False  False
# 1  False  False  False
# 2  False  False   True
# 3  False   True  False

# %%
# is there any column null.
# if answer is True，说明哪一列上有Missing Data
df.isnull().any()
# Out:
# Name     False
# Age       True
# Color     True
# dtype: bool

# %% [markdown]
# ## Dropping Missing Data

# %%
# drop row
df.dropna()
# Out:
#     Name   Age Color
# 0   Fred  22.0   Red
# 1  Sally  29.0  Blue

# %% [markdown]
# ## Inserting Data for Missing Data

# %%
df.fillna('missing')
# Out:
#      Name      Age    Color
# 0    Fred       22      Red
# 1   Sally       29     Blue
# 2  George       24  missing
# 3    Fido  missing    Black

# %%
df.fillna({'Age':df['Age'].median(),
      'Color':'Pink'})
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0   Pink
# 3    Fido  24.0  Black

# %%
# 跟上一行一样, axis = 0
# 跟上一列一样， axis = 1
display( df.fillna(method='ffill') )
print()
display( df.fillna(method='ffill', axis=1) )
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0   Blue
# 3    Fido  24.0  Black
#      Name   Age  Color
# 0    Fred    22    Red
# 1   Sally    29   Blue
# 2  George    24     24
# 3    Fido  Fido  Black

# %%
# 跟下一行一样， axis = 0
# 跟下一列一样， axis = 1
display( df.fillna(method='bfill') )
print()
display( df.fillna(method='bfill', axis = 1) )
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0  Black
# 3    Fido   NaN  Black
#      Name    Age  Color
# 0    Fred     22    Red
# 1   Sally     29   Blue
# 2  George     24    NaN
# 3    Fido  Black  Black

# %%
# 这玩意不是很懂
df.interpolate()
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0    NaN
# 3    Fido  24.0  Black

# %%
# 替换，我会直接用fillna，可以指定规则
df.replace(np.nan, value=-1)
# Out:
#      Name   Age  Color
# 0    Fred  22.0    Red
# 1   Sally  29.0   Blue
# 2  George  24.0     -1
# 3    Fido  -1.0  Black

# %%
df.fillna({'Age':-100,
      'Color':'Pink'})
# Out:
#      Name    Age  Color
# 0    Fred   22.0    Red
# 1   Sally   29.0   Blue
# 2  George   24.0   Pink
# 3    Fido -100.0  Black
